# %% [markdown]
# ### **Coding exercises**
#
# - Improve general code understanding
# - Improve ability to work with Copilot
#
# :)

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# # Printing 1
#
# **Follow-up prompt submitted to Copilot:** “Show examples with print formatting”
#
# name = "Ada"
# age = 27
# print(f"Name: {name}, Age: {age}")

# %% [markdown]
# # Printing 2
#
# **Follow-up prompt submitted to Copilot:** “Create a price table formatting example”
#
# ## Pricing
#
# > Save ~2 months with annual billing.
#
# | Plan      | Monthly | Annual | Users | Storage | Support          | Notes              |
# |-----------|--------:|-------:|------:|--------:|------------------|--------------------|
# | Starter   | €9      | €90    | 1     | 5 GB    | Email            | For individuals    |
# | **Pro**   | **€19** | **€190** | 5     | 50 GB   | Email + Chat     | **Most popular**   |
# | Business  | €49     | €490   | 25    | 200 GB  | Priority 24/7    | Teams & orgs       |
#
# **All plans include:** ✅ Unlimited projects · ✅ Secure cloud sync · ✅ Export
